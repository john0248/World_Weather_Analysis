# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import random
import sys
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Call url for Weather Map API in Imperial units 
url= "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | axim
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | tuatapere
# Processing Record 5 of Set 1 | kahului
# Processing Record 6 of Set 1 | karaman
# Processing Record 7 of Set 1 | alofi
# Processing Record 8 of Set 1 | lompoc
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | portland
# Processing Record 13 of Set 1 | kulunda
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | acari
# Processing Record 16 of Set 1 | samarai
# Processing Record 17 of Set 1 | kaihua
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | lorengau
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | tura
# Processing Record 24 of Set 1 | dhidhdhoo
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | lensk
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | christchurch
# Processing Record 30 of Set 1 | tawnat
# City not found. Skipping...
# Processing Record 31 of Set 1 | rawson
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | makakilo city
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | esperance
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | kruisfontein
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | coquimbo
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | riyadh
# Processing Record 47 of Set 1 | pucallpa
# Processing Record 48 of Set 1 | kintampo
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | havelock
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | namatanai
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | grindavik
# Processing Record 9 of Set 2 | tazovskiy
# Processing Record 10 of Set 2 | asau
# Processing Record 11 of Set 2 | burnie
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | narsaq
# Processing Record 14 of Set 2 | ranfurly
# Processing Record 15 of Set 2 | bagting
# Processing Record 16 of Set 2 | kudahuvadhoo
# Processing Record 17 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 18 of Set 2 | oussouye
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | shingu
# Processing Record 21 of Set 2 | sobolevo
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 2 | tottori
# Processing Record 27 of Set 2 | terrace
# Processing Record 28 of Set 2 | minab
# Processing Record 29 of Set 2 | fortuna
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | kodiak
# Processing Record 36 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 2 | marsa matruh
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | soyo
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | pitsunda
# Processing Record 42 of Set 2 | tamandare
# Processing Record 43 of Set 2 | wladyslawowo
# Processing Record 44 of Set 2 | hirtshals
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | artvin
# Processing Record 47 of Set 2 | voh
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | arroyo
# Processing Record 50 of Set 2 | solnechnyy
# Processing Record 1 of Set 3 | matara
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | atherton
# Processing Record 4 of Set 3 | severo-kurilsk
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | deputatskiy
# Processing Record 7 of Set 3 | wageningen
# Processing Record 8 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 3 | west wendover
# Processing Record 10 of Set 3 | kaeo
# Processing Record 11 of Set 3 | san policarpo
# Processing Record 12 of Set 3 | sayyan
# Processing Record 13 of Set 3 | parintins
# Processing Record 14 of Set 3 | grand gaube
# Processing Record 15 of Set 3 | kendari
# Processing Record 16 of Set 3 | aktau
# Processing Record 17 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 3 | waingapu
# Processing Record 19 of Set 3 | buckeye
# Processing Record 20 of Set 3 | vila
# Processing Record 21 of Set 3 | tuensang
# Processing Record 22 of Set 3 | kavieng
# Processing Record 23 of Set 3 | lokosovo
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | yongan
# Processing Record 26 of Set 3 | saskylakh
# Processing Record 27 of Set 3 | airai
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | manali
# Processing Record 30 of Set 3 | tekeli
# Processing Record 31 of Set 3 | cidreira
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | pochutla
# Processing Record 34 of Set 3 | bilibino
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | micheweni
# Processing Record 37 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 3 | bethel
# Processing Record 39 of Set 3 | faanui
# Processing Record 40 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 3 | kapaa
# Processing Record 42 of Set 3 | vagur
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | vila velha
# Processing Record 45 of Set 3 | huanren
# Processing Record 46 of Set 3 | kavaratti
# Processing Record 47 of Set 3 | oranjemund
# Processing Record 48 of Set 3 | pisco
# Processing Record 49 of Set 3 | jiayuguan
# Processing Record 50 of Set 3 | westport
# Processing Record 1 of Set 4 | pokosnoye
# Processing Record 2 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 4 | zhigansk
# Processing Record 5 of Set 4 | sisimiut
# Processing Record 6 of Set 4 | loikaw
# Processing Record 7 of Set 4 | sedhiou
# Processing Record 8 of Set 4 | nikolskoye
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | djambala
# Processing Record 11 of Set 4 | salalah
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | santa isabel do rio negro
# Processing Record 14 of Set 4 | mwene-ditu
# Processing Record 15 of Set 4 | aklavik
# Processing Record 16 of Set 4 | marrakesh
# Processing Record 17 of Set 4 | hovd
# Processing Record 18 of Set 4 | alice springs
# Processing Record 19 of Set 4 | lakheri
# Processing Record 20 of Set 4 | nome
# Processing Record 21 of Set 4 | kattivakkam
# Processing Record 22 of Set 4 | marihatag
# Processing Record 23 of Set 4 | amahai
# Processing Record 24 of Set 4 | mahebourg
# Processing Record 25 of Set 4 | champerico
# Processing Record 26 of Set 4 | lishu
# Processing Record 27 of Set 4 | bambanglipuro
# Processing Record 28 of Set 4 | pasni
# Processing Record 29 of Set 4 | musson
# Processing Record 30 of Set 4 | guerrero negro
# Processing Record 31 of Set 4 | belle fourche
# Processing Record 32 of Set 4 | lata
# Processing Record 33 of Set 4 | faya
# Processing Record 34 of Set 4 | longyearbyen
# Processing Record 35 of Set 4 | horve
# Processing Record 36 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 4 | barrie
# Processing Record 38 of Set 4 | ahipara
# Processing Record 39 of Set 4 | huarmey
# Processing Record 40 of Set 4 | gat
# Processing Record 41 of Set 4 | rabat
# Processing Record 42 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 43 of Set 4 | upernavik
# Processing Record 44 of Set 4 | ponta do sol
# Processing Record 45 of Set 4 | antofagasta
# Processing Record 46 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 47 of Set 4 | altay
# Processing Record 48 of Set 4 | yulara
# Processing Record 49 of Set 4 | juybar
# Processing Record 50 of Set 4 | sal rei
# Processing Record 1 of Set 5 | buenos aires
# Processing Record 2 of Set 5 | mushie
# Processing Record 3 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 5 | ponta delgada
# Processing Record 7 of Set 5 | saint-francois
# Processing Record 8 of Set 5 | bathsheba
# Processing Record 9 of Set 5 | saint-philippe
# Processing Record 10 of Set 5 | ancud
# Processing Record 11 of Set 5 | margate
# Processing Record 12 of Set 5 | katsuura
# Processing Record 13 of Set 5 | valleyview
# Processing Record 14 of Set 5 | bud
# Processing Record 15 of Set 5 | aksu
# Processing Record 16 of Set 5 | astoria
# Processing Record 17 of Set 5 | kilindoni
# Processing Record 18 of Set 5 | altamont
# Processing Record 19 of Set 5 | wadi maliz
# Processing Record 20 of Set 5 | saint-georges
# Processing Record 21 of Set 5 | broken hill
# Processing Record 22 of Set 5 | cascais
# Processing Record 23 of Set 5 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 24 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 5 | provideniya
# Processing Record 26 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 5 | moose factory
# Processing Record 28 of Set 5 | te anau
# Processing Record 29 of Set 5 | paamiut
# Processing Record 30 of Set 5 | klichka
# Processing Record 31 of Set 5 | standish
# Processing Record 32 of Set 5 | seminole
# Processing Record 33 of Set 5 | kapoeta
# Processing Record 34 of Set 5 | yaroslavskaya
# Processing Record 35 of Set 5 | soria
# Processing Record 36 of Set 5 | olafsvik
# Processing Record 37 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 5 | boa vista
# Processing Record 39 of Set 5 | necochea
# Processing Record 40 of Set 5 | waipawa
# Processing Record 41 of Set 5 | cockburn town
# Processing Record 42 of Set 5 | klaksvik
# Processing Record 43 of Set 5 | hambantota
# Processing Record 44 of Set 5 | burdur
# Processing Record 45 of Set 5 | deniliquin
# Processing Record 46 of Set 5 | comodoro rivadavia
# Processing Record 47 of Set 5 | weligama
# Processing Record 48 of Set 5 | richards bay
# Processing Record 49 of Set 5 | cap malheureux
# Processing Record 50 of Set 5 | kurumkan
# Processing Record 1 of Set 6 | vidalia
# Processing Record 2 of Set 6 | los llanos de aridane
# Processing Record 3 of Set 6 | port lincoln
# Processing Record 4 of Set 6 | villa vazquez
# City not found. Skipping...
# Processing Record 5 of Set 6 | kumba
# Processing Record 6 of Set 6 | beringovskiy
# Processing Record 7 of Set 6 | jerecuaro
# Processing Record 8 of Set 6 | litovko
# Processing Record 9 of Set 6 | vikramasingapuram
# Processing Record 10 of Set 6 | saint-joseph
# Processing Record 11 of Set 6 | vila franca do campo
# Processing Record 12 of Set 6 | quatre cocos
# Processing Record 13 of Set 6 | xiaoshi
# Processing Record 14 of Set 6 | melfort
# Processing Record 15 of Set 6 | avera
# Processing Record 16 of Set 6 | apodi
# Processing Record 17 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 6 | caravelas
# Processing Record 19 of Set 6 | lebu
# Processing Record 20 of Set 6 | suntar
# Processing Record 21 of Set 6 | palafrugell
# Processing Record 22 of Set 6 | zaysan
# Processing Record 23 of Set 6 | el dorado
# Processing Record 24 of Set 6 | husavik
# Processing Record 25 of Set 6 | nancha
# Processing Record 26 of Set 6 | honningsvag
# Processing Record 27 of Set 6 | lahat
# Processing Record 28 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 6 | buraydah
# Processing Record 30 of Set 6 | omsukchan
# Processing Record 31 of Set 6 | dese
# Processing Record 32 of Set 6 | gravdal
# Processing Record 33 of Set 6 | sao jose da coroa grande
# Processing Record 34 of Set 6 | srednekolymsk
# Processing Record 35 of Set 6 | bubaque
# Processing Record 36 of Set 6 | morgan city
# Processing Record 37 of Set 6 | codrington
# Processing Record 38 of Set 6 | myaundzha
# Processing Record 39 of Set 6 | bay roberts
# Processing Record 40 of Set 6 | gurupi
# Processing Record 41 of Set 6 | pailon
# Processing Record 42 of Set 6 | sistranda
# Processing Record 43 of Set 6 | cumra
# Processing Record 44 of Set 6 | pouebo
# Processing Record 45 of Set 6 | salinopolis
# Processing Record 46 of Set 6 | muisne
# Processing Record 47 of Set 6 | mattawa
# Processing Record 48 of Set 6 | bambous virieux
# Processing Record 49 of Set 6 | yanliang
# Processing Record 50 of Set 6 | vandavasi
# Processing Record 1 of Set 7 | niquelandia
# Processing Record 2 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 7 | januaria
# Processing Record 4 of Set 7 | xadani
# City not found. Skipping...
# Processing Record 5 of Set 7 | berdigestyakh
# Processing Record 6 of Set 7 | maumere
# Processing Record 7 of Set 7 | pacific grove
# Processing Record 8 of Set 7 | yarmouth
# Processing Record 9 of Set 7 | fairbanks
# Processing Record 10 of Set 7 | benghazi
# Processing Record 11 of Set 7 | ostrovnoy
# Processing Record 12 of Set 7 | leningradskiy
# Processing Record 13 of Set 7 | lodja
# Processing Record 14 of Set 7 | port hedland
# Processing Record 15 of Set 7 | hamilton
# Processing Record 16 of Set 7 | sahuaripa
# Processing Record 17 of Set 7 | jalu
# Processing Record 18 of Set 7 | sibiti
# Processing Record 19 of Set 7 | hokitika
# Processing Record 20 of Set 7 | port blair
# Processing Record 21 of Set 7 | pleasanton
# Processing Record 22 of Set 7 | khorinsk
# Processing Record 23 of Set 7 | ravar
# Processing Record 24 of Set 7 | alta floresta
# Processing Record 25 of Set 7 | souillac
# Processing Record 26 of Set 7 | mizque
# Processing Record 27 of Set 7 | luderitz
# Processing Record 28 of Set 7 | muktagachha
# City not found. Skipping...
# Processing Record 29 of Set 7 | dawei
# Processing Record 30 of Set 7 | trelew
# Processing Record 31 of Set 7 | cullinan
# Processing Record 32 of Set 7 | cody
# Processing Record 33 of Set 7 | rathdrum
# Processing Record 34 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 7 | saint george
# Processing Record 36 of Set 7 | vestmannaeyjar
# Processing Record 37 of Set 7 | brunswick
# Processing Record 38 of Set 7 | sao filipe
# Processing Record 39 of Set 7 | pozo colorado
# Processing Record 40 of Set 7 | fukue
# Processing Record 41 of Set 7 | shangrao
# Processing Record 42 of Set 7 | shimoda
# Processing Record 43 of Set 7 | sola
# Processing Record 44 of Set 7 | safford
# Processing Record 45 of Set 7 | copiapo
# Processing Record 46 of Set 7 | santiago
# Processing Record 47 of Set 7 | belen
# Processing Record 48 of Set 7 | bardiyah
# Processing Record 49 of Set 7 | korla
# Processing Record 50 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 8 | igbo ora
# Processing Record 2 of Set 8 | chibuto
# Processing Record 3 of Set 8 | sumbe
# Processing Record 4 of Set 8 | balkhash
# Processing Record 5 of Set 8 | riohacha
# Processing Record 6 of Set 8 | mount gambier
# Processing Record 7 of Set 8 | saint-cyr-sur-loire
# Processing Record 8 of Set 8 | kargasok
# Processing Record 9 of Set 8 | meulaboh
# Processing Record 10 of Set 8 | ribeira grande
# Processing Record 11 of Set 8 | saravan
# Processing Record 12 of Set 8 | talnakh
# Processing Record 13 of Set 8 | balabac
# Processing Record 14 of Set 8 | lavrentiya
# Processing Record 15 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 8 | hasaki
# Processing Record 17 of Set 8 | shenzhen
# Processing Record 18 of Set 8 | decatur
# Processing Record 19 of Set 8 | otuzco
# Processing Record 20 of Set 8 | bagrami
# Processing Record 21 of Set 8 | brae
# Processing Record 22 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 8 | puerto quijarro
# Processing Record 24 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 8 | churapcha
# Processing Record 26 of Set 8 | shu
# Processing Record 27 of Set 8 | la primavera
# Processing Record 28 of Set 8 | college
# Processing Record 29 of Set 8 | sergach
# Processing Record 30 of Set 8 | baruun-urt
# Processing Record 31 of Set 8 | rajapur
# Processing Record 32 of Set 8 | storm lake
# Processing Record 33 of Set 8 | wagar
# Processing Record 34 of Set 8 | huambo
# Processing Record 35 of Set 8 | coruripe
# Processing Record 36 of Set 8 | kaduqli
# Processing Record 37 of Set 8 | tignere
# Processing Record 38 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 8 | la ronge
# Processing Record 40 of Set 8 | emerald
# Processing Record 41 of Set 8 | qianan
# Processing Record 42 of Set 8 | praia da vitoria
# Processing Record 43 of Set 8 | hansi
# Processing Record 44 of Set 8 | hay river
# Processing Record 45 of Set 8 | mattru
# Processing Record 46 of Set 8 | safranbolu
# Processing Record 47 of Set 8 | windhoek
# Processing Record 48 of Set 8 | carutapera
# Processing Record 49 of Set 8 | verkhoyansk
# Processing Record 50 of Set 8 | kiunga
# Processing Record 1 of Set 9 | la union
# Processing Record 2 of Set 9 | puerto varas
# Processing Record 3 of Set 9 | dudinka
# Processing Record 4 of Set 9 | borogontsy
# Processing Record 5 of Set 9 | krasnooktyabrskiy
# Processing Record 6 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 9 | nyurba
# Processing Record 8 of Set 9 | elk plain
# Processing Record 9 of Set 9 | lucapa
# Processing Record 10 of Set 9 | sept-iles
# Processing Record 11 of Set 9 | aykhal
# Processing Record 12 of Set 9 | dongying
# Processing Record 13 of Set 9 | strezhevoy
# Processing Record 14 of Set 9 | lashio
# Processing Record 15 of Set 9 | vanimo
# Processing Record 16 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 9 | hendijan
# City not found. Skipping...
# Processing Record 18 of Set 9 | qaqortoq
# Processing Record 19 of Set 9 | clyde river
# Processing Record 20 of Set 9 | belinskiy
# Processing Record 21 of Set 9 | paracatu
# Processing Record 22 of Set 9 | kosh-agach
# Processing Record 23 of Set 9 | high level
# Processing Record 24 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 9 | batagay-alyta
# Processing Record 26 of Set 9 | sinnamary
# Processing Record 27 of Set 9 | beyneu
# Processing Record 28 of Set 9 | malabo
# Processing Record 29 of Set 9 | watsa
# Processing Record 30 of Set 9 | kandry
# Processing Record 31 of Set 9 | tashla
# Processing Record 32 of Set 9 | russellville
# Processing Record 33 of Set 9 | ulaangom
# Processing Record 34 of Set 9 | ifo
# Processing Record 35 of Set 9 | asandh
# Processing Record 36 of Set 9 | bengkulu
# Processing Record 37 of Set 9 | griffith
# Processing Record 38 of Set 9 | garachine
# Processing Record 39 of Set 9 | himora
# City not found. Skipping...
# Processing Record 40 of Set 9 | acajutla
# Processing Record 41 of Set 9 | phalombe
# Processing Record 42 of Set 9 | erenhot
# Processing Record 43 of Set 9 | yumen
# Processing Record 44 of Set 9 | kenai
# Processing Record 45 of Set 9 | juneau
# Processing Record 46 of Set 9 | robertson
# Processing Record 47 of Set 9 | tocopilla
# Processing Record 48 of Set 9 | lima
# Processing Record 49 of Set 9 | maceio
# Processing Record 50 of Set 9 | mehamn
# Processing Record 1 of Set 10 | rio gallegos
# Processing Record 2 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 10 | zhongshu
# Processing Record 4 of Set 10 | nicoya
# Processing Record 5 of Set 10 | noyabrsk
# Processing Record 6 of Set 10 | mpika
# Processing Record 7 of Set 10 | bolobo
# Processing Record 8 of Set 10 | sabya
# Processing Record 9 of Set 10 | mango
# Processing Record 10 of Set 10 | kuala lipis
# Processing Record 11 of Set 10 | kuusamo
# Processing Record 12 of Set 10 | nizwa
# Processing Record 13 of Set 10 | ballitoville
# Processing Record 14 of Set 10 | sioux lookout
# Processing Record 15 of Set 10 | barranca de upia
# Processing Record 16 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 17 of Set 10 | angra
# City not found. Skipping...
# Processing Record 18 of Set 10 | toungoo
# City not found. Skipping...
# Processing Record 19 of Set 10 | lincoln
# Processing Record 20 of Set 10 | ilulissat
# Processing Record 21 of Set 10 | tautira
# Processing Record 22 of Set 10 | saint anthony
# Processing Record 23 of Set 10 | bautzen
# Processing Record 24 of Set 10 | gazanjyk
# Processing Record 25 of Set 10 | katima mulilo
# Processing Record 26 of Set 10 | salinas
# Processing Record 27 of Set 10 | inuvik
# Processing Record 28 of Set 10 | mayor pablo lagerenza
# Processing Record 29 of Set 10 | udachnyy
# Processing Record 30 of Set 10 | ola
# Processing Record 31 of Set 10 | antalaha
# Processing Record 32 of Set 10 | vega baja
# Processing Record 33 of Set 10 | bilma
# Processing Record 34 of Set 10 | lakhdenpokhya
# Processing Record 35 of Set 10 | tucurui
# Processing Record 36 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 10 | araouane
# Processing Record 38 of Set 10 | scarborough
# Processing Record 39 of Set 10 | koungou
# Processing Record 40 of Set 10 | boguchany
# Processing Record 41 of Set 10 | lazaro cardenas
# Processing Record 42 of Set 10 | tiksi
# Processing Record 43 of Set 10 | chipinge
# Processing Record 44 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 10 | dali
# Processing Record 46 of Set 10 | viedma
# Processing Record 47 of Set 10 | okhotsk
# Processing Record 48 of Set 10 | bergama
# Processing Record 49 of Set 10 | berlevag
# Processing Record 50 of Set 10 | chifeng
# Processing Record 1 of Set 11 | arrecife
# Processing Record 2 of Set 11 | cam ranh
# Processing Record 3 of Set 11 | gaya
# Processing Record 4 of Set 11 | berezovyy
# Processing Record 5 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 6 of Set 11 | cowra
# Processing Record 7 of Set 11 | shymkent
# Processing Record 8 of Set 11 | selizharovo
# Processing Record 9 of Set 11 | lazarev
# Processing Record 10 of Set 11 | karasburg
# Processing Record 11 of Set 11 | oistins
# Processing Record 12 of Set 11 | olga
# Processing Record 13 of Set 11 | bowen
# Processing Record 14 of Set 11 | shelby
# Processing Record 15 of Set 11 | babu
# Processing Record 16 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 11 | pevek
# Processing Record 18 of Set 11 | padang
# Processing Record 19 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 11 | hobyo
# Processing Record 21 of Set 11 | arzgir
# Processing Record 22 of Set 11 | norman wells
# Processing Record 23 of Set 11 | puerto leguizamo
# Processing Record 24 of Set 11 | severo-yeniseyskiy
# Processing Record 25 of Set 11 | bandarbeyla
# Processing Record 26 of Set 11 | xiaoweizhai
# Processing Record 27 of Set 11 | karratha
# Processing Record 28 of Set 11 | beloha
# Processing Record 29 of Set 11 | purpe
# Processing Record 30 of Set 11 | poum
# Processing Record 31 of Set 11 | hirara
# Processing Record 32 of Set 11 | vostok
# Processing Record 33 of Set 11 | jumla
# Processing Record 34 of Set 11 | nelson bay
# Processing Record 35 of Set 11 | boyolangu
# Processing Record 36 of Set 11 | chervone
# Processing Record 37 of Set 11 | turukhansk
# Processing Record 38 of Set 11 | novaya zaimka
# Processing Record 39 of Set 11 | torbay
# Processing Record 40 of Set 11 | sao joao da barra
# Processing Record 41 of Set 11 | yuzhno-kurilsk
# Processing Record 42 of Set 11 | calvinia
# Processing Record 43 of Set 11 | korem
# Processing Record 44 of Set 11 | rincon
# Processing Record 45 of Set 11 | raga
# Processing Record 46 of Set 11 | bugasong
# Processing Record 47 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 48 of Set 11 | laguna
# Processing Record 49 of Set 11 | havoysund
# Processing Record 50 of Set 11 | velyka bilozerka
# Processing Record 1 of Set 12 | maniitsoq
# Processing Record 2 of Set 12 | paka
# Processing Record 3 of Set 12 | umm kaddadah
# Processing Record 4 of Set 12 | bristol
# Processing Record 5 of Set 12 | mudon
# Processing Record 6 of Set 12 | camana
# Processing Record 7 of Set 12 | bali chak
# Processing Record 8 of Set 12 | chunoyar
# Processing Record 9 of Set 12 | umba
# Processing Record 10 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 11 of Set 12 | shelburne
# Processing Record 12 of Set 12 | wangqing
# Processing Record 13 of Set 12 | mandalgovi
# Processing Record 14 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 12 | pullman
# Processing Record 16 of Set 12 | biltine
# Processing Record 17 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 18 of Set 12 | marsh harbour
# Processing Record 19 of Set 12 | kimbe
# Processing Record 20 of Set 12 | charters towers
# Processing Record 21 of Set 12 | moron
# Processing Record 22 of Set 12 | biasca
# Processing Record 23 of Set 12 | kurchum
# Processing Record 24 of Set 12 | potiskum
# Processing Record 25 of Set 12 | pitimbu
# Processing Record 26 of Set 12 | arman
# Processing Record 27 of Set 12 | doha
# Processing Record 28 of Set 12 | hami
# Processing Record 29 of Set 12 | katherine
# Processing Record 30 of Set 12 | batsfjord
# Processing Record 31 of Set 12 | idenao
# Processing Record 32 of Set 12 | clinton
# Processing Record 33 of Set 12 | nogales
# Processing Record 34 of Set 12 | namibe
# Processing Record 35 of Set 12 | san fernando
# Processing Record 36 of Set 12 | nanortalik
# Processing Record 37 of Set 12 | innisfail
# Processing Record 38 of Set 12 | aksarka
# Processing Record 39 of Set 12 | durres
# Processing Record 40 of Set 12 | northam
# Processing Record 41 of Set 12 | prado
# Processing Record 42 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 12 | aswan
# Processing Record 44 of Set 12 | jinji
# Processing Record 45 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 12 | leh
# Processing Record 47 of Set 12 | santarem
# Processing Record 48 of Set 12 | eresos
# Processing Record 49 of Set 12 | monterey
# Processing Record 50 of Set 12 | vitim
# Processing Record 1 of Set 13 | lopatino
# Processing Record 2 of Set 13 | brumado
# Processing Record 3 of Set 13 | pangnirtung
# Processing Record 4 of Set 13 | port said
# Processing Record 5 of Set 13 | tatsinskaya
# City not found. Skipping...
# Processing Record 6 of Set 13 | apiai
# Processing Record 7 of Set 13 | buluang
# Processing Record 8 of Set 13 | san cristobal
# Processing Record 9 of Set 13 | hofn
# Processing Record 10 of Set 13 | dunedin
# Processing Record 11 of Set 13 | borkenes
# Processing Record 12 of Set 13 | nargana
# Processing Record 13 of Set 13 | bereda
# Processing Record 14 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 13 | babahoyo
# Processing Record 16 of Set 13 | hermiston
# Processing Record 17 of Set 13 | marsala
# Processing Record 18 of Set 13 | tiznit
# Processing Record 19 of Set 13 | kawalu
# Processing Record 20 of Set 13 | lokken verk
# City not found. Skipping...
# Processing Record 21 of Set 13 | vardo
# Processing Record 22 of Set 13 | motygino
# Processing Record 23 of Set 13 | prince rupert
# Processing Record 24 of Set 13 | kansanshi
# Processing Record 25 of Set 13 | itarema
# Processing Record 26 of Set 13 | tromso
# Processing Record 27 of Set 13 | cayenne
# Processing Record 28 of Set 13 | mnogovershinnyy
# Processing Record 29 of Set 13 | lamont
# Processing Record 30 of Set 13 | xinyang
# Processing Record 31 of Set 13 | laurel
# Processing Record 32 of Set 13 | port hardy
# Processing Record 33 of Set 13 | panalingaan
# Processing Record 34 of Set 13 | ambilobe
# Processing Record 35 of Set 13 | felipe carrillo puerto
# Processing Record 36 of Set 13 | maragogi
# Processing Record 37 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 38 of Set 13 | bundaberg
# Processing Record 39 of Set 13 | maarianhamina
# Processing Record 40 of Set 13 | belmonte
# Processing Record 41 of Set 13 | birjand
# Processing Record 42 of Set 13 | isla mujeres
# Processing Record 43 of Set 13 | benjamin aceval
# Processing Record 44 of Set 13 | titel
# Processing Record 45 of Set 13 | grand-lahou
# Processing Record 46 of Set 13 | manono
# Processing Record 47 of Set 13 | kaka
# Processing Record 48 of Set 13 | russell
# Processing Record 49 of Set 13 | taoudenni
# Processing Record 50 of Set 13 | kitimat
# Processing Record 1 of Set 14 | general elizardo aquino
# Processing Record 2 of Set 14 | fort nelson
# Processing Record 3 of Set 14 | patan
# Processing Record 4 of Set 14 | buchanan
# Processing Record 5 of Set 14 | chaoyang
# Processing Record 6 of Set 14 | lesosibirsk
# Processing Record 7 of Set 14 | orotukan
# Processing Record 8 of Set 14 | coihaique
# Processing Record 9 of Set 14 | tias
# Processing Record 10 of Set 14 | kamaishi
# Processing Record 11 of Set 14 | kindia
# Processing Record 12 of Set 14 | melbu
# Processing Record 13 of Set 14 | kismayo
# Processing Record 14 of Set 14 | saveh
# Processing Record 15 of Set 14 | athabasca
# Processing Record 16 of Set 14 | starogard gdanski
# Processing Record 17 of Set 14 | blind river
# Processing Record 18 of Set 14 | port hawkesbury
# Processing Record 19 of Set 14 | dalbandin
# Processing Record 20 of Set 14 | waitati
# Processing Record 21 of Set 14 | gainesville
# Processing Record 22 of Set 14 | ozernovskiy
# Processing Record 23 of Set 14 | lasa
# Processing Record 24 of Set 14 | krasnoselkup
# Processing Record 25 of Set 14 | sitka
# Processing Record 26 of Set 14 | qingan
# City not found. Skipping...
# Processing Record 27 of Set 14 | puerto narino
# Processing Record 28 of Set 14 | yangjiang
# Processing Record 29 of Set 14 | andenes
# Processing Record 30 of Set 14 | gollere
# City not found. Skipping...
# Processing Record 31 of Set 14 | san quintin
# Processing Record 32 of Set 14 | bansko
# Processing Record 33 of Set 14 | clovis
# Processing Record 34 of Set 14 | la palma
# Processing Record 35 of Set 14 | mikhaylovskoye
# Processing Record 36 of Set 14 | fergus falls
# Processing Record 37 of Set 14 | visby
# Processing Record 38 of Set 14 | nichinan
# Processing Record 39 of Set 14 | merauke
# Processing Record 40 of Set 14 | povenets
# Processing Record 41 of Set 14 | bastia
# Processing Record 42 of Set 14 | kiama
# Processing Record 43 of Set 14 | yurga
# Processing Record 44 of Set 14 | severodvinsk
# Processing Record 45 of Set 14 | kwinana
# Processing Record 46 of Set 14 | podares
# Processing Record 47 of Set 14 | progreso
# Processing Record 48 of Set 14 | walvis bay
# Processing Record 49 of Set 14 | tommot
# Processing Record 50 of Set 14 | lundazi
# Processing Record 1 of Set 15 | presidencia roque saenz pena
# Processing Record 2 of Set 15 | nhulunbuy
# Processing Record 3 of Set 15 | port moresby
# Processing Record 4 of Set 15 | segou
# Processing Record 5 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 15 | kedrovyy
# Processing Record 7 of Set 15 | superior
# Processing Record 8 of Set 15 | dingle
# Processing Record 9 of Set 15 | verkhnyaya inta
# Processing Record 10 of Set 15 | adrar
# Processing Record 11 of Set 15 | mount isa
# Processing Record 12 of Set 15 | isangel
# Processing Record 13 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 14 of Set 15 | ouadda
# Processing Record 15 of Set 15 | half moon bay
# Processing Record 16 of Set 15 | garowe
# Processing Record 17 of Set 15 | borba
# Processing Record 18 of Set 15 | kibondo
# Processing Record 19 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 15 | senneterre
# Processing Record 21 of Set 15 | sokoto
# Processing Record 22 of Set 15 | pokhara
# Processing Record 23 of Set 15 | coahuayana
# Processing Record 24 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 25 of Set 15 | touros
# Processing Record 26 of Set 15 | ryabovo
# Processing Record 27 of Set 15 | mondlo
# Processing Record 28 of Set 15 | isakly
# Processing Record 29 of Set 15 | stonewall
# Processing Record 30 of Set 15 | russkaya polyana
# Processing Record 31 of Set 15 | lufilufi
# Processing Record 32 of Set 15 | tezu
# Processing Record 33 of Set 15 | saint-paul
# Processing Record 34 of Set 15 | monrovia
# Processing Record 35 of Set 15 | svetlogorsk
# Processing Record 36 of Set 15 | blonduos
# City not found. Skipping...
# Processing Record 37 of Set 15 | muros
# Processing Record 38 of Set 15 | dauriya
# Processing Record 39 of Set 15 | taybad
# Processing Record 40 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 41 of Set 15 | namtsy
# Processing Record 42 of Set 15 | dalby
# Processing Record 43 of Set 15 | gumdag
# Processing Record 44 of Set 15 | shizunai
# Processing Record 45 of Set 15 | caranavi
# Processing Record 46 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 47 of Set 15 | dzhebariki-khaya
# Processing Record 48 of Set 15 | teahupoo
# Processing Record 49 of Set 15 | hammerfest
# Processing Record 50 of Set 15 | bull savanna
# Processing Record 1 of Set 16 | balsas
# Processing Record 2 of Set 16 | saint-augustin
# Processing Record 3 of Set 16 | sabha
# Processing Record 4 of Set 16 | nishihara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(f'Len of city data: {len(city_data)}')
# Out:
# Len of city data: 685

# %%
# Convert the array of dictionaries to a pandas dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Atuona      PF  -9.8000 -139.0333     79.05        63          22
# 1       Axim      GH   4.8699   -2.2405     81.07        85          95
# 2    Rikitea      PF -23.1203 -134.9692     79.72        72         100
# 3  Tuatapere      NZ -46.1333  167.6833     62.01        73           0
# 4    Kahului      US  20.8947 -156.4700     77.00        73          40
#
#    Wind Speed Current Description
# 0        2.37          few clouds
# 1        7.23          light rain
# 2        4.99     overcast clouds
# 3        1.99           clear sky
# 4       14.97          light rain

# %%
# Create output file
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# export the city_data into a csv
city_data_df.to_csv(output_data_file,index_label="City_ID")
city_data_df.tail(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 675          Shizunai      JP  42.3339  142.3669     36.09        70
# 676          Caranavi      BO -15.8167  -67.5500     65.16        96
# 677  Dzhebariki-Khaya      RU  62.2167  135.8000     -2.61        81
# 678          Teahupoo      PF -17.8333 -149.2667     87.80        66
# 679        Hammerfest      NO  70.6634   23.6821     23.00        74
# 680      Bull Savanna      JM  17.8868  -77.5902     76.37        70
# 681            Balsas      BR  -7.5325  -46.0356     76.24        88
# 682    Saint-Augustin      CA  51.2260  -58.6502     30.87        82
# 683             Sabha      LY  27.0377   14.4283     63.12        34
# 684         Nishihara      JP  26.1842  127.7558     64.40        51
#
#      Cloudiness  Wind Speed Current Description
# 675          41        7.63    scattered clouds
# 676          51        1.43       broken clouds
# 677         100        2.82     overcast clouds
# 678          40        9.22          light rain
# 679          40       11.50    scattered clouds
# 680          15        2.64          few clouds
# 681          81        3.91       broken clouds
# 682         100       23.17     overcast clouds
# 683          23       17.00          few clouds
# 684          75        9.22       broken clouds
